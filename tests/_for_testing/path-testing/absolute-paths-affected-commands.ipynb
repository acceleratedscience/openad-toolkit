# %% [markdown]
# # Commands affected by path change

# %%
# Create sample data
import pandas as pd
import os

data = {'index': [1, 2, 3], 'smiles': ['Cc1cc(C)cc(C)c1', 'C=CCC=C', 'CC(C)Cc1ccccc1']}
df = pd.DataFrame(data)
filename = 'sample_data.csv'
df.to_csv(filename, index=False)

print(f"Saved '{filename}' in the current directory.")
# Out:
# Saved 'sample_data.csv' in the current directory.

# %%
# Display data
# %openad display data './sample_data.csv'
# Out:
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`as dataframe`/`save [as '<filename.csv>']` <br>
# <style type="text/css">
# </style>
# <table id="T_37e52">
#   <thead>
#     <tr>
#       <th id="T_37e52_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_37e52_level0_col1" class="col_heading level0 col1" >smiles</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_37e52_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_37e52_row0_col1" class="data row0 col1" >Cc1cc(C)cc(C)c1</td>
#     </tr>
#     <tr>
#       <td id="T_37e52_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_37e52_row1_col1" class="data row1 col1" >C=CCC=C</td>
#     </tr>
#     <tr>
#       <td id="T_37e52_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_37e52_row2_col1" class="data row2 col1" >CC(C)Cc1ccccc1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Result save
# %openad result save as './dump/output-1'
# Out:
# <span style="color: #dc0">The destination directory does not exist, create it?</span> <br>
# (y/n):  y
# <span style="color: #090">Result saved: <span style="color: #dc0">/Users/themoenen/Documents/Dump/_testing/dump/output-1.csv</span></span> <br>

# %%
# Import
# %openad import './sample_data.csv'
# Out:
# <span style="color: #090">File saved to workspace as <span style="color: #dc0">sample_data.csv</span></span> <br>

# %%
# Copy
# %openad copy './sample_data.csv' to './dump/output-2.csv'
# Out:
# <span style="color: #dc0">Rename file from sample_data.csv to output-2.csv?</span> <br>
# (y/n):  y
# <span style="color: #090">File saved: <span style="color: #dc0">/Users/themoenen/Documents/Dump/_testing/dump/output-2.csv</span></span> <br>

# %%
# Move
# %openad move './dump/output-2.csv' to './output-3.csv'
# Out:
# <span style="color: #dc0">Rename file from output-2.csv to output-3.csv?</span> <br>
# (y/n):  y
# <span style="color: #090">File saved: <span style="color: #dc0">/Users/themoenen/Documents/Dump/_testing/output-3.csv</span></span> <br>

# %%
# Remove
# %openad remove './output-3.csv'
# Out:
# <span style="color: #ffa500">⚠️  You're about to delete a file outside of your workspace:</span> <br>
# <span style="color: #ccc">/Users/themoenen/Documents/Dump/_testing/output-3.csv</span> <br>
# <span style="color: #dc0">Continue?</span> <br>
# (y/n):  y
# <span style="color: #090">File removed: <span style="color: #dc0">/Users/themoenen/Documents/Dump/_testing/output-3.csv</span></span> <br>

# %%
# Model commands
# %openad moler generate with MoLeRDefaultGenerator data save_as './dump/output-4.csv'
# Out:
# Output()
# <span style="color: #090">Result saved: <span style="color: #dc0">/Users/themoenen/Documents/Dump/_testing/dump/output-4.csv</span></span> <br>
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`as dataframe`/`save [as '<filename.csv>']` <br>
# <style type="text/css">
# </style>
# <table id="T_df9c3">
#   <thead>
#     <tr>
#       <th id="T_df9c3_level0_col0" class="col_heading level0 col0" >result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_df9c3_row0_col0" class="data row0 col0" >O=C1C2=CC=C(C3=CC=CC=C3)C=C=C2OC2=CC=CC=C12</td>
#     </tr>
#     <tr>
#       <td id="T_df9c3_row1_col0" class="data row1 col0" >CC(=O)NC1=NC2=CC(OCC3=CC=CN(CC4=CC=C(Cl)C=C4)C3=O)=CC=C2N1</td>
#     </tr>
#     <tr>
#       <td id="T_df9c3_row2_col0" class="data row2 col0" >CCN1C(=O)C2=CC=CC=C2N=C1NC(C)C(=O)NCC(=O)N=[N+]=[N-]</td>
#     </tr>
#     <tr>
#       <td id="T_df9c3_row3_col0" class="data row3 col0" >CC(=O)N1CCCC1C1=NC2=CC=C(C(C)(C)CCCC(C)C)C=C2NC1=NC1=CC=C(O)C=C1</td>
#     </tr>
#     <tr>
#       <td id="T_df9c3_row4_col0" class="data row4 col0" >N=C(N)NCCCCOC1=CC=C(Br)C(Cl)=N1</td>
#     </tr>
#     <tr>
#       <td id="T_df9c3_row5_col0" class="data row5 col0" >O=C1C2=CC=C(C3=NN=CO3)C=C2N=CN1CC1=CC=C(C2=CC=CC=C2)C=C1</td>
#     </tr>
#     <tr>
#       <td id="T_df9c3_row6_col0" class="data row6 col0" >O=CCCCCCN1C=CC2=CC=CC=C21</td>
#     </tr>
#     <tr>
#       <td id="T_df9c3_row7_col0" class="data row7 col0" >CCOC(=O)C1=CC2=CC(CC(C)C)=CC=C2N=C1C1=CC=C(Br)C=C1</td>
#     </tr>
#     <tr>
#       <td id="T_df9c3_row8_col0" class="data row8 col0" >CC1=C(C#N)C=C(NC(=O)NC2CCCCC2)N1CC#N</td>
#     </tr>
#     <tr>
#       <td id="T_df9c3_row9_col0" class="data row9 col0" >CC1=CNN=C1NC(=O)COC1=CC=C(Cl)C=C1Cl</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Get model service result -- save_as not implemented
# %openad get model service <service_name> result '<result_id>

# %%
# Load molecules
# %openad load molecules from file './sample_data.csv'
# Out:
# <span style="color: #090">Successfully loaded <span style="color: #dc0">3</span> molecules into the working set</span> <br>

# %%
# Export molecule
# %openad export molecule dopamine as file
# Out:
# <span style="color: #dc0">The destination file already exists, overwrite?</span> <br>
# (y/n):  y
# <span style="color: #090">Molecule saved to workspace as <span style="color: #dc0">dopamine.sdf</span></span> <br>

# %%
# Export molecule working set
# %openad add molecule dopamine
# %openad export molecules as './dump/my_molecules'
# Out:
# <span style="color: #dc0">Add molecule <span style="color: #090">dopamine</span> to your molecule working set?</span> <br>
# (y/n):  y
# <span style="color: #090">Molecule <span style="color: #dc0">dopamine</span> was added</span> <br>
# <span style="color: #090">Result set saved: <span style="color: #dc0">/Users/themoenen/Documents/Dump/_testing/dump/my_molecules.csv</span></span> <br>

# %%
# Edit config -- terminal only

# %%
# Open file
# %openad open './sample_data.csv'

# %% [markdown]
# ### Clean up testing files

# %%
# %openad remove './dump'
# Out:
# <span style="color: #ffa500">⚠️  You're about to delete a directory outside of your workspace:</span> <br>
# <span style="color: #ccc">/Users/themoenen/Documents/Dump/_testing/dump</span> <br>
# <span style="color: #dc0">Continue?</span> <br>
# (y/n):  y
# <span style="color: #090">Directory removed: <span style="color: #dc0">/Users/themoenen/Documents/Dump/_testing/dump</span></span> <br>
