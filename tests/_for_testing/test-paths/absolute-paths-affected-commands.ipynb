# %% [markdown]
# # Commands affected by path change

# %%
# Create sample data
import pandas as pd
import os

data = {'index': [1, 2, 3], 'smiles': ['Cc1cc(C)cc(C)c1', 'C=CCC=C', 'CC(C)Cc1ccccc1']}
df = pd.DataFrame(data)
filename = 'sample_data.csv'
df.to_csv(filename, index=False)

print(f"Saved '{filename}' in the current directory.")
# Out:
# Saved 'sample_data.csv' in the current directory.

# %%
# Display data
# %openad display data './sample_data.csv'
# Out:
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`as dataframe`/`save [as '<filename.csv>']` <br>
# <style type="text/css">
# </style>
# <table id="T_60290">
#   <thead>
#     <tr>
#       <th id="T_60290_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_60290_level0_col1" class="col_heading level0 col1" >smiles</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_60290_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_60290_row0_col1" class="data row0 col1" >Cc1cc(C)cc(C)c1</td>
#     </tr>
#     <tr>
#       <td id="T_60290_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_60290_row1_col1" class="data row1 col1" >C=CCC=C</td>
#     </tr>
#     <tr>
#       <td id="T_60290_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_60290_row2_col1" class="data row2 col1" >CC(C)Cc1ccccc1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Result save
# %openad result save as './dump/output-1'
# Out:
# <span style="color: #dc0">The destination directory does not exist, create it?</span> <br>
# (y/n):  y
# <span style="color: #090">Result saved: <span style="color: #dc0">/Users/themoenen/Local/GitHub/openad/tests/_for_testing/test-paths/dump/output-1.csv</span></span> <br>

# %%
# Import
# %openad import './sample_data.csv'
# Out:
# <span style="color: #dc0">The destination file already exists, overwrite?</span> <br>
# (y/n):  y
# <span style="color: #090">File saved to workspace as <span style="color: #dc0">sample_data.csv</span></span> <br>

# %%
# Copy
# %openad copy './sample_data.csv' to './dump/output-2.csv'
# Out:
# <span style="color: #dc0">Rename file from sample_data.csv to output-2.csv?</span> <br>
# (y/n):  y
# <span style="color: #090">File saved: <span style="color: #dc0">/Users/themoenen/Local/GitHub/openad/tests/_for_testing/test-paths/dump/output-2.csv</span></span> <br>

# %%
# Move
# %openad move './dump/output-2.csv' to './output-3.csv'
# Out:
# <span style="color: #dc0">Rename file from output-2.csv to output-3.csv?</span> <br>
# (y/n):  y
# <span style="color: #090">File saved: <span style="color: #dc0">/Users/themoenen/Local/GitHub/openad/tests/_for_testing/test-paths/output-3.csv</span></span> <br>

# %%
# Remove
# %openad remove './output-3.csv'
# Out:
# <span style="color: #ffa500">⚠️  You're about to delete a file outside of your workspace:</span> <br>
# <span style="color: #ccc">/Users/themoenen/Local/GitHub/openad/tests/_for_testing/test-paths/output-3.csv</span> <br>
# <span style="color: #dc0">Continue?</span> <br>
# (y/n):  y
# <span style="color: #090">File removed: <span style="color: #dc0">/Users/themoenen/Local/GitHub/openad/tests/_for_testing/test-paths/output-3.csv</span></span> <br>

# %%
# Model commands
# %openad moler generate with MoLeRDefaultGenerator data save_as './dump/output-4.csv'
# Out:
# <span style="color: #d00">Not a valid command</span> <br>
# <span style="color: #ccc">moler generate with MoLeRDefaultGenerator data save_as './dump/output-4.csv' <br>
# ^</span> <br>
# <span style="color: #dc0">Commands starting with "m"</span> <br>
# - `move '<source_file>' to '<destination_path>' [ force ]` <br>
# - `copy '<source_file>' to '<destination_path>' [ force ]` <br>
# - `model auth list` <br>
# - `model auth add group <auth_group> with '<auth_token>'` <br>
# - `model auth remove group <auth_group>` <br>
# - `model auth add service <service_name> to group <auth_group>` <br>
# - `model auth remove service <service_name>` <br>
# - `model service status` <br>
# - `model service describe <service_name>` <br>
# - `model catalog list` <br>
# - `model service up <service_name> [ no_gpu ]` <br>
# - `model service local up <service_name> [ no_gpu ]` <br>
# - `model service down <service_name>` <br>
# - `merge molecules|mols data from dataframe <dataframe> [ enrich ]` <br>
# ...

# %%
# Get model service result -- save_as not implemented
# %openad get model service <service_name> result '<result_id>

# %%
# Load molecules
# %openad load molecules from file './sample_data.csv'
# Out:
# <span style="color: #090">Successfully loaded <span style="color: #dc0">3</span> molecules into the working set</span> <br>

# %%
# Export molecule
# %openad export molecule dopamine as file
# Out:
# <span style="color: #dc0">The destination file already exists, overwrite?</span> <br>
# (y/n):  y
# <span style="color: #090">Molecule saved to workspace as <span style="color: #dc0">dopamine.sdf</span></span> <br>

# %%
# Export molecule working set
# %openad add molecule dopamine
# %openad export molecules as './dump/my_molecules'
# Out:
# <span style="color: #dc0">Add molecule <span style="color: #090">dopamine</span> to your molecule working set?</span> <br>
# (y/n):  y
# <span style="color: #090">Molecule <span style="color: #dc0">dopamine</span> was added</span> <br>
# <span style="color: #090">Result set saved: <span style="color: #dc0">/Users/themoenen/Local/GitHub/openad/tests/_for_testing/test-paths/dump/my_molecules.csv</span></span> <br>

# %%
# Edit config -- terminal only

# %%
# Open file
# %openad open './sample_data.csv'

# %% [markdown]
# ### Clean up testing files

# %%
# %openad remove './dump'
# %openad remove './sample_data.csv'
# Out:
# <span style="color: #d00">The selected file <span style="color: #dc0">/Users/themoenen/Local/GitHub/openad/tests/_for_testing/test-paths/dump</span> does not exist</span> <br>
# <span style="color: #ffa500">⚠️  You're about to delete a file outside of your workspace:</span> <br>
# <span style="color: #ccc">/Users/themoenen/Local/GitHub/openad/tests/_for_testing/test-paths/sample_data.csv</span> <br>
# <span style="color: #dc0">Continue?</span> <br>
# (y/n):  y
# <span style="color: #090">File removed: <span style="color: #dc0">/Users/themoenen/Local/GitHub/openad/tests/_for_testing/test-paths/sample_data.csv</span></span> <br>
