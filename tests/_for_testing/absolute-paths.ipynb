# %% [markdown]
# # Legacy Import/Export/Copy

# %%
import os
cwd = os.getcwd()
this_file_path = os.path.join(cwd, 'absolute-paths.ipynb')
export_path = os.path.join(cwd, '_delete-me.ipynb')

# %% [markdown]
# ### Legacy import
# ```
# import from '<external_source_file>' to '<workspace_file>'
# ```

# %%
# Import this file into your workspace
# %openad import from '{this_file_path}' to 'absolute-paths.ipynb'

# %% [markdown]
# ### Legacy export
# ```
# export from '<workspace_file>' to '<external_file>'
# ```

# %%
# Export imported file to this folder
# %openad export from 'test-absolute-paths.ipynb' to '{export_path}'

# %% [markdown]
# ### Legacy copy
# ```
# copy file '<workspace_file>' to '<other_workspace_name>'
# ```

# %%
# Create TEST workspace for testing copy
# %openad clear sessions
# %openad create workspace test
# %openad set workspace default

# %%
# Copy imported file to another workspace
# %openad copy file 'absolute-paths.ipynb' to 'test'

# %% [markdown]
# # New Import/Copy/Move

# %%
# Import
# %openad import '{this_file_path}'
# Out:
# 1
# 2
# <span style="color: #090">File saved to workspace as <span style="color: #dc0">absolute-paths.ipynb</span></span> <br>

# %%
# Copy
# From workspace to your home directory
# %openad copy 'absolute-paths.ipynb' to '~/_delete-me-homedir.ipynb'
# Out:
# <span style="color: #dc0">Rename file from absolute-paths.ipynb to _delete-me-homedir.ipynb?</span> <br>
# (y/n):  y
# <span style="color: #090">File saved to workspace as <span style="color: #dc0">Users/themoenen/_delete-me-homedir.ipynb</span></span> <br>

# %%
# Move
# From home dir to this folder
# %openad move '~/_delete-me-homedir.ipynb' to './_test.ipynb'
# Out:
# <span style="color: #dc0">Rename file from _delete-me-homedir.ipynb to _test.ipynb?</span> <br>
# (y/n):  y
# <span style="color: #090">File saved to <span style="color: #dc0">/Users/themoenen/.openad/workspaces/DEFAULT/_test.ipynb</span></span> <br>
