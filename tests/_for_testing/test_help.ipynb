# %%
# %openad list files ?
# %openad import ?
# %openad move ?
# %openad copy ?
# %openad remove '<filename>' ?
# %openad open '<filename>' ?
# %openad show '<filename>' ?

# %%
# %openad openad ?
# %openad get status ?
# %openad display history ?
# %openad clear sessions ?

# %%
# %openad intro ?
# %openad docs ?

# %%
# %openad tell me ?
# %openad set llm  ?
# %openad clear llm ?

# %%
# %openad show mmol ?

# %%
# %openad add molecule ?
# %openad remove molecule ?
# %openad list molecules ?
# %openad show molecules ?
# %openad enrich molecules ?
# %openad clear analysis cache ?
# %openad display sources ?
# %openad rename molecule ?
# %openad load molecules ?
# %openad load molecules ?
# %openad merge molecules ?
# %openad export molecules ?
# %openad clear molecules ?

# %%
# %openad create run ?
# %openad remove run ?
# %openad save run ?
# %openad run ?
# %openad list runs ?
# %openad display run ?

# %%
# %openad display molecule ?
# %openad show molecule ?
# %openad show molset ?
# %openad @ ?
# %openad export molecule ?

# %%
# %openad display data ?
# %openad result save ?
# %openad result open ?
# %openad result edit ?
# %openad result copy ?
# %openad result display ?
# %openad result as dataframe ?
# %openad edit config ?

# %%
# %openad set workspace ?
# %openad get workspace ?
# %openad create workspace ?
# %openad remove workspace ?
# %openad list workspaces ?

# %%
# %openad intro
# %openad docs
# %openad ?
# %openad ? set
# %openad set ?

# %%
# %openad ?
