# %%
import pandas as pd
mol = %openadd export molecule aspirin
row={}
# print(mol["property_sources"])
# print("---")
# print(mol["properties"]["record"])
for key in mol["identifiers"]:
    if mol["identifiers"][key]:
        row[key] = mol["identifiers"][key]
for key in mol["properties"]:
    if (
        mol["properties"][key] is None
    ):  # To avoid None values to be stored as "None" string
        row[key] = ""
    else:
        row[key] = mol["properties"][key]
        print(f"\n\n--- {key}:")
        print(mol["properties"][key])

        data = [row]
# pd.DataFrame(data)
# Out:
# --- atom_stereo_count:
# 0
#
#
# --- atoms:
# ...
