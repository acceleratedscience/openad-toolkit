# %%
# %openad rxn predict retro {smiles} using (max_steps=5) use cache return df
# Out:
# Output()
# <span style="color: #d00">The server returned an empty response</span> <br>
# <span style="color: #ccc">{'response': {'payload': None, 'metadata': {'uiMessages': {'errors': [{'code': None, 'message': 'RESOURCE_NOT_FOUND', 'type': 'ERROR', 'description': None, 'fieldId': None, 'target': 'TOAST', 'duration': 10000}], 'infos': [], 'warnings': []}, 'extendedPagination': {}}}}</span> <br>
